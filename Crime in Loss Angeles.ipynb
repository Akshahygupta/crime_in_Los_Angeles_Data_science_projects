# %% [markdown]
# ## This dataset analyzes information on sex crimes, a part 1 crime as defined by the FBI, in Los Angeles during the year 2022
# ## This analysis is done with Python and the pandas, matplotlib, and csv libraries, with the goal of producing further understanding of the characteristics of these events.
# ## The source of this data can be found below
# # Source: https://data.lacity.org/Public-Safety/Crime-Data-from-2020-to-Present/2nrs-mtv8
# ### This data is only as good as the data reported in the database

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # load the data

# %%
df = pd.read_csv('Crime_Data_from_2020_to_Present.csv')
df['Date'] = pd.to_datetime(df['DATE OCC'])
df = df.loc[(df['Date'].dt.year==2022)]# & (df['Date'].dt.month== 8)]

# %% [markdown]
# # Let's check the first few rows and the shape of the data

# %%
df.head()
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 408582  220216262  09/08/2022 12:00:00 AM  09/08/2022 12:00:00 AM      1445
# 408583  221809626  04/23/2022 12:00:00 AM  04/22/2022 12:00:00 AM      2100
# 408584  221711121  07/10/2022 12:00:00 AM  07/10/2022 12:00:00 AM       200
# 408585  220805283  01/24/2022 12:00:00 AM  01/22/2022 12:00:00 AM      1445
# 408586  221821212  11/27/2022 12:00:00 AM  11/27/2022 12:00:00 AM      1635
#
#         AREA   AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 408582     2     Rampart          275         2     624
# 408583    18   Southeast         1862         1     510
# 408584    17  Devonshire         1781         1     230
# 408585     8     West LA          855         1     341
# 408586    18   Southeast         1826         1     210
#
#                                               Crm Cd Desc  ...  Status Desc  \
# 408582                           BATTERY - SIMPLE ASSAULT  ...  Adult Other
# 408583                                   VEHICLE - STOLEN  ...  Invest Cont
# 408584     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...  Invest Cont
# 408585  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...  Invest Cont
# 408586                                            ROBBERY  ...  Invest Cont
#
#         Crm Cd 1 Crm Cd 2 Crm Cd 3  Crm Cd 4  \
# 408582     624.0      NaN      NaN       NaN
# 408583     510.0      NaN      NaN       NaN
# 408584     230.0      NaN      NaN       NaN
# 408585     341.0      NaN      NaN       NaN
# 408586     210.0      NaN      NaN       NaN
#
#                                        LOCATION  \
# 408582  1000 S  BURLINGTON                   AV
# 408583          SAN PEDRO                    ST
# 408584  8800    OSO                          AV
# 408585  1600    CAMDEN                       AV
# 408586                                     91ST
#
#                            Cross Street      LAT       LON       Date
# 408582                              NaN  34.0502 -118.2765 2022-09-08
# 408583  120TH                        ST  33.9237 -118.2696 2022-04-22
# 408584                              NaN  34.2299 -118.5754 2022-07-10
# 408585                              NaN  34.0501 -118.4439 2022-01-22
# 408586                          COMPTON  33.9543 -118.2475 2022-11-27
#
# [5 rows x 29 columns]

# %%
df.shape
# Out:
# (233899, 29)

# %% [markdown]
# # Now let's start reviewing the crimes in LA, narrowing in on sex crimes

# %%
df['Crm Cd Desc'].value_counts().iloc[:10].sort_values().plot(kind="barh", title = "Types of Crimes")
# Out:
# <Axes: title={'center': 'Types of Crimes'}>

# %% [markdown]
# # There are 21 geographic areas in the city of Los Angeles, as defined by the LAPD

# %%
df['AREA NAME'].value_counts().sort_values().plot(kind="barh", color = '#1ABC9C', title = 'Total of Crime Events by Area')
# Out:
# <Axes: title={'center': 'Total of Crime Events by Area'}>

# %%
sex_crimes = df[df['Crm Cd Desc'].str.contains('SEX CRIMES|RAPE')].copy()
sex_crimes.head()
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 408785  220218121  10/05/2022 12:00:00 AM  05/01/2022 12:00:00 AM       800
# 409266  220122725  10/18/2022 12:00:00 AM  10/18/2022 12:00:00 AM       900
# 409389  220105324  01/23/2022 12:00:00 AM  01/22/2022 12:00:00 AM      2000
# 409790  220210149  05/10/2022 12:00:00 AM  05/09/2022 12:00:00 AM      1500
# 409872  221918107  12/18/2022 12:00:00 AM  12/18/2022 12:00:00 AM       330
#
#         AREA AREA NAME  Rpt Dist No  Part 1-2  Crm Cd      Crm Cd Desc  ...  \
# 408785     2   Rampart          256         1     121   RAPE, FORCIBLE  ...
# 409266     1   Central          164         1     121   RAPE, FORCIBLE  ...
# 409389     1   Central          147         1     121   RAPE, FORCIBLE  ...
# 409790     2   Rampart          216         1     121   RAPE, FORCIBLE  ...
# 409872    19   Mission         1961         1     122  RAPE, ATTEMPTED  ...
#
#         Status Desc  Crm Cd 1 Crm Cd 2 Crm Cd 3  Crm Cd 4  \
# 408785  Invest Cont     121.0    812.0      NaN       NaN
# 409266  Invest Cont     121.0      NaN      NaN       NaN
# 409389  Invest Cont     121.0    998.0      NaN       NaN
# 409790  Invest Cont     121.0    812.0      NaN       NaN
# 409872  Invest Cont     122.0      NaN      NaN       NaN
#
#                                       LOCATION  Cross Street      LAT  \
# 408785                                     6TH      WILSHIRE  34.0565
# 409266  600 S  SPRING                       ST           NaN  34.0460
# 409389                                     5TH    SAN JULIAN  34.0446
# 409790  400 N  LAKE                         ST           NaN  34.0707
# 409872                               SEPULVEDA       PLUMMER  34.2428
#
#              LON       Date
# 408785 -118.2724 2022-05-01
# 409266 -118.2510 2022-10-18
# 409389 -118.2450 2022-01-22
# 409790 -118.2693 2022-05-09
# 409872 -118.4676 2022-12-18
#
# [5 rows x 29 columns]

# %%
sex_crimes['AREA NAME'].value_counts().sort_values().plot(kind="barh", color = '#33ff74', title = 'Sex Crimes by Area in 2022')
# Out:
# <Axes: title={'center': 'Sex Crimes by Area in 2022'}>

# %% [markdown]
# # Now let's query for sex crimes and create a new dataframe with the copy command

# %%
sex_crimes['Crm Cd Desc'].value_counts().sort_values().plot(kind="barh", stacked=True,title = 'Sex Crimes by Type in 2022', color=['blue', 'green'])
# Out:
# <Axes: title={'center': 'Sex Crimes by Type in 2022'}>

# %% [markdown]
# # With the next few graphs, let's review the sex crimes victims gender, descent, and age

# %%
sex_crimes['Vict Sex'].value_counts().sort_values().plot(kind="bar", color = '#ffdd33', title = 'Sex Crimes Victims by Gender in 2022')
# Out:
# <Axes: title={'center': 'Sex Crimes Victims by Gender in 2022'}>

# %%
descent_order = ['A', 'B', 'H', 'O', 'W']

sns.countplot(x = "Vict Descent", data = sex_crimes, order = descent_order, palette="Set1").set(title='Sex Crimes Victims by Descent')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'A'),
#   Text(1, 0, 'B'),
#   Text(2, 0, 'H'),
#   Text(3, 0, 'O'),
#   Text(4, 0, 'W')])

# %% [markdown]
# # Let's do some data wrangling to categorize the age field

# %%
sex_crimes.loc[sex_crimes['Vict Age']<=17, 'age_group'] = 'less than 18'
sex_crimes.loc[sex_crimes['age_group']=='less than 18', 'age_sort'] = 1.0
sex_crimes.loc[sex_crimes['Vict Age'].between(18,28), 'age_group'] = '18 - 28'
sex_crimes.loc[sex_crimes['age_group']=='18 - 28', 'age_sort'] = 2
sex_crimes.loc[sex_crimes['Vict Age'].between(29,39), 'age_group'] = '29 - 39'
sex_crimes.loc[sex_crimes['age_group']=='29 - 39', 'age_sort'] = 3
sex_crimes.loc[sex_crimes['Vict Age'].between(40,49), 'age_group'] = '40 - 49'
sex_crimes.loc[sex_crimes['age_group']=='40 - 49', 'age_sort'] = 4
sex_crimes.loc[sex_crimes['Vict Age'].between(50,59), 'age_group'] = '50 - 59'
sex_crimes.loc[sex_crimes['age_group']=='50 - 59', 'age_sort'] = 5
sex_crimes.loc[sex_crimes['Vict Age'].between(60,69), 'age_group'] = '60 - 69'
sex_crimes.loc[sex_crimes['age_group']=='60 - 69', 'age_sort'] = 6
sex_crimes.loc[sex_crimes['Vict Age']>=70, 'age_group'] = 'older than 69'
sex_crimes.loc[sex_crimes['age_group']=='70 - 200', 'age_sort'] = 7
sex_crimes.tail(2)
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 641935  221900906  11/21/2022 12:00:00 AM  11/07/2022 12:00:00 AM      1325
# 642355  221006425  03/06/2022 12:00:00 AM  02/25/2022 12:00:00 AM       200
#
#         AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd     Crm Cd Desc  ...  \
# 641935    19      Mission         1998         1     121  RAPE, FORCIBLE  ...
# 642355    10  West Valley         1067         1     121  RAPE, FORCIBLE  ...
#
#        Crm Cd 2  Crm Cd 3 Crm Cd 4                                  LOCATION  \
# 641935    812.0     998.0      NaN  14100    ROSCOE                       BL
# 642355    998.0       NaN      NaN   5100    BALBOA                       BL
#
#         Cross Street      LAT       LON       Date     age_group age_sort
# 641935           NaN  34.2216 -118.4402 2022-11-07  less than 18      1.0
# 642355           NaN  34.1660 -118.5095 2022-02-25       18 - 28      2.0
#
# [2 rows x 31 columns]

# %%
sex_crimes = sex_crimes.sort_values('age_sort')
sex_crimes.head()
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 408785  220218121  10/05/2022 12:00:00 AM  05/01/2022 12:00:00 AM       800
# 569923  221300573  02/15/2022 12:00:00 AM  02/14/2022 12:00:00 AM      1900
# 568948  221017436  12/08/2022 12:00:00 AM  11/05/2022 12:00:00 AM      2100
# 567533  221224472  11/30/2022 12:00:00 AM  11/26/2022 12:00:00 AM       900
# 566644  220614895  08/20/2022 12:00:00 AM  08/20/2022 12:00:00 AM       150
#
#         AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd     Crm Cd Desc  ...  \
# 408785     2      Rampart          256         1     121  RAPE, FORCIBLE  ...
# 569923    13       Newton         1345         1     121  RAPE, FORCIBLE  ...
# 568948    10  West Valley         1001         1     121  RAPE, FORCIBLE  ...
# 567533    12  77th Street         1232         1     121  RAPE, FORCIBLE  ...
# 566644     6    Hollywood          636         1     121  RAPE, FORCIBLE  ...
#
#        Crm Cd 2  Crm Cd 3 Crm Cd 4                                 LOCATION  \
# 408785    812.0       NaN      NaN                                      6TH
# 569923    998.0       NaN      NaN  3400 S  CENTRAL                      AV
# 568948      NaN       NaN      NaN          ARMINTA                      ST
# 567533    812.0       NaN      NaN          SLAUSON                      AV
# 566644    998.0       NaN      NaN  1700    WILCOX                       AV
#
#                            Cross Street      LAT       LON       Date  \
# 408785                         WILSHIRE  34.0565 -118.2724 2022-05-01
# 569923                              NaN  34.0128 -118.2565 2022-02-14
# 568948  VANALDEN                     AV  34.2138 -118.5492 2022-11-05
# 567533  CRENSHAW                     BL  33.9890 -118.3309 2022-11-26
# 566644                              NaN  34.1016 -118.3310 2022-08-20
#
#            age_group age_sort
# 408785  less than 18      1.0
# 569923  less than 18      1.0
# 568948  less than 18      1.0
# 567533  less than 18      1.0
# 566644  less than 18      1.0
#
# [5 rows x 31 columns]

# %% [markdown]
# # For this last graph let's group sex crim victims by age

# %%
sns.set_theme(style="darkgrid")
age_order = ["less than 18", '18 - 28', '29 - 39', '40 - 49', '50 - 59']#, '60 - 69', 'older than 69']
sns.countplot(x = "age_group", data = sex_crimes, order = age_order, palette="Set2").set(title='Sex Crime Victims by Age')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'less than 18'),
#   Text(1, 0, '18 - 28'),
#   Text(2, 0, '29 - 39'),
#   Text(3, 0, '40 - 49'),
#   Text(4, 0, '50 - 59')])

# %% [markdown]
# # With these graphs we can learn about the occurrence of reported sex crimes in the city of Los Angeles. For the calendar year 2022, we learn that victims of sex crimes are more likely female, ofe black or hispanic descent and that victims are most likely to be between the age of 18 - 28, as of mid-February. Further we see that sex crimes are more likely to occur in the 77th and Central LAPD geographic areas.
# # This analysis helps to break down some of the characteristics of this Part 1 crime
